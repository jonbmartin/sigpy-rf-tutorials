# %% [markdown]
#    # Shinnar-Le Roux RF Pulse Design with SigPy

# %%
# %matplotlib notebook
import sys
sys.path.append(r"/home/jonathan/PycharmProjects/sigpy-rf")

# %load_ext autoreload
# %autoreload 2
import numpy as np
import sigpy as sp
import sigpy.mri as mr
import sigpy.mri.rf as rf
import sigpy.plot as pl
import scipy.signal as signal
import matplotlib.pyplot as pyplot
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
#    ## Parameters for a time-bandwidth 4, linear-phase excitation

# %%
tb = 8
N = 128
d1 = 0.01
d2 = 0.01
ptype = 'ex'
ftype = 'ls'

# %% [markdown]
#    ## Design the excitation pulse

# %%
pulse = rf.slr.dzrf(N, tb, ptype, ftype, d1, d2, False)
pl.LinePlot(pulse, mode='r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Simulate the excitation pulse's Mxy profile

# %%
[a, b] = rf.sim.abrm(pulse, np.arange(-2*tb, 2*tb, 0.01), True)
Mxy = 2*np.multiply(np.conj(a), b)
pl.LinePlot(Mxy)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Nfreqs = 2000
mInit = np.repeat([[0, 0, 1]], Nfreqs, axis=0)
f0 = np.linspace(-2*tb/(N),2*tb/(N),Nfreqs)
t1 = np.full(Nfreqs, np.infty)
t2 = np.full(Nfreqs, np.infty)
dt = 1
mFinal = mr.bloch_forward(mInit, pulse, f0, t1, t2, dt)
pl.LinePlot(mFinal[:,0]+1j*mFinal[:,1],mode='m')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Parameters for a time-bandwidth 8, minimum-phase inversion

# %%
tb = 8
N = 128
d1 = 0.01
d2 = 0.01
ptype = 'inv'
ftype = 'min'

# %% [markdown]
# ## Design the inversion pulse

# %%
pulse = rf.slr.dzrf(N, tb, ptype, ftype, d1, d2)
pl.LinePlot(pulse, mode='r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Simulate the inversion pulse's Mz profile

# %%
[a, b] = rf.sim.abrm(pulse, np.arange(-2*tb, 2*tb, 0.01))
Mz = 1-2*np.abs(b)**2
pl.LinePlot(Mz.T, mode='r')
print(np.shape(Mz))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (3200,)

# %%
Nfreqs = 2000
mInit = np.repeat([[0, 0, 1]], Nfreqs, axis=0)
dt = 1
f0 = np.linspace(-2*tb/(N), 2*tb/(N), Nfreqs)
t1 = np.full(Nfreqs, np.infty)
t2 = np.full(Nfreqs, np.infty)
mFinal = mr.bloch_forward(mInit, pulse, f0, t1, t2, dt)
pl.LinePlot(mFinal[:,2], mode='r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Design a root-flipped saturation pulse

# %%
tb = 12
N = 128
d1 = 0.01
d2 = 0.001
ptype = 'sat'
ftype = 'min'
# conventional pulse
pulse = rf.slr.dzrf(N, tb, ptype, ftype, d1, d2)
pl.LinePlot(pulse, mode='r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# root-flipped pulse
tb = 12
N = 128
d1 = 0.01
d2 = 0.001
flip = np.pi/2
ptype = 'sat'
[bsf, d1, d2] = rf.slr.calcRipples(ptype, d1, d2)
b = bsf*rf.slr.dzmp(N, tb, d1, d2)
b = b[::-1]
[pulse, bRootFlipped] = rf.slr.rootFlip(b, d1, flip, tb)

pyplot.figure()
pyplot.plot(np.abs(pulse))
# Out:
# Evaluating root-flip pattern 0 out of 2048
# Evaluating root-flip pattern 20 out of 2048
# Evaluating root-flip pattern 40 out of 2048
# Evaluating root-flip pattern 60 out of 2048
# Evaluating root-flip pattern 80 out of 2048
# Evaluating root-flip pattern 100 out of 2048
# Evaluating root-flip pattern 120 out of 2048
# Evaluating root-flip pattern 140 out of 2048
# Evaluating root-flip pattern 160 out of 2048
# Evaluating root-flip pattern 180 out of 2048
# Evaluating root-flip pattern 200 out of 2048
# Evaluating root-flip pattern 220 out of 2048
# Evaluating root-flip pattern 240 out of 2048
# Evaluating root-flip pattern 260 out of 2048
# Evaluating root-flip pattern 280 out of 2048
# Evaluating root-flip pattern 300 out of 2048
# Evaluating root-flip pattern 320 out of 2048
# Evaluating root-flip pattern 340 out of 2048
# Evaluating root-flip pattern 360 out of 2048
# Evaluating root-flip pattern 380 out of 2048
# Evaluating root-flip pattern 400 out of 2048
# Evaluating root-flip pattern 420 out of 2048
# Evaluating root-flip pattern 440 out of 2048
# Evaluating root-flip pattern 460 out of 2048
# Evaluating root-flip pattern 480 out of 2048
# Evaluating root-flip pattern 500 out of 2048
# Evaluating root-flip pattern 520 out of 2048
# Evaluating root-flip pattern 540 out of 2048
# Evaluating root-flip pattern 560 out of 2048
# Evaluating root-flip pattern 580 out of 2048
# Evaluating root-flip pattern 600 out of 2048
# Evaluating root-flip pattern 620 out of 2048
# Evaluating root-flip pattern 640 out of 2048
# Evaluating root-flip pattern 660 out of 2048
# Evaluating root-flip pattern 680 out of 2048
# Evaluating root-flip pattern 700 out of 2048
# Evaluating root-flip pattern 720 out of 2048
# Evaluating root-flip pattern 740 out of 2048
# Evaluating root-flip pattern 760 out of 2048
# Evaluating root-flip pattern 780 out of 2048
# Evaluating root-flip pattern 800 out of 2048
# Evaluating root-flip pattern 820 out of 2048
# Evaluating root-flip pattern 840 out of 2048
# Evaluating root-flip pattern 860 out of 2048
# Evaluating root-flip pattern 880 out of 2048
# Evaluating root-flip pattern 900 out of 2048
# Evaluating root-flip pattern 920 out of 2048
# Evaluating root-flip pattern 940 out of 2048
# Evaluating root-flip pattern 960 out of 2048
# Evaluating root-flip pattern 980 out of 2048
# Evaluating root-flip pattern 1000 out of 2048
# Evaluating root-flip pattern 1020 out of 2048
# Evaluating root-flip pattern 1040 out of 2048
# Evaluating root-flip pattern 1060 out of 2048
# Evaluating root-flip pattern 1080 out of 2048
# Evaluating root-flip pattern 1100 out of 2048
# Evaluating root-flip pattern 1120 out of 2048
# Evaluating root-flip pattern 1140 out of 2048
# Evaluating root-flip pattern 1160 out of 2048
# Evaluating root-flip pattern 1180 out of 2048
# Evaluating root-flip pattern 1200 out of 2048
# Evaluating root-flip pattern 1220 out of 2048
# Evaluating root-flip pattern 1240 out of 2048
# Evaluating root-flip pattern 1260 out of 2048
# Evaluating root-flip pattern 1280 out of 2048
# Evaluating root-flip pattern 1300 out of 2048
# Evaluating root-flip pattern 1320 out of 2048
# Evaluating root-flip pattern 1340 out of 2048
# Evaluating root-flip pattern 1360 out of 2048
# Evaluating root-flip pattern 1380 out of 2048
# Evaluating root-flip pattern 1400 out of 2048
# Evaluating root-flip pattern 1420 out of 2048
# Evaluating root-flip pattern 1440 out of 2048
# Evaluating root-flip pattern 1460 out of 2048
# Evaluating root-flip pattern 1480 out of 2048
# Evaluating root-flip pattern 1500 out of 2048
# Evaluating root-flip pattern 1520 out of 2048
# Evaluating root-flip pattern 1540 out of 2048
# Evaluating root-flip pattern 1560 out of 2048
# Evaluating root-flip pattern 1580 out of 2048
# Evaluating root-flip pattern 1600 out of 2048
# Evaluating root-flip pattern 1620 out of 2048
# Evaluating root-flip pattern 1640 out of 2048
# Evaluating root-flip pattern 1660 out of 2048
# Evaluating root-flip pattern 1680 out of 2048
# Evaluating root-flip pattern 1700 out of 2048
# Evaluating root-flip pattern 1720 out of 2048
# Evaluating root-flip pattern 1740 out of 2048
# Evaluating root-flip pattern 1760 out of 2048
# Evaluating root-flip pattern 1780 out of 2048
# Evaluating root-flip pattern 1800 out of 2048
# Evaluating root-flip pattern 1820 out of 2048
# Evaluating root-flip pattern 1840 out of 2048
# Evaluating root-flip pattern 1860 out of 2048
# Evaluating root-flip pattern 1880 out of 2048
# Evaluating root-flip pattern 1900 out of 2048
# Evaluating root-flip pattern 1920 out of 2048
# Evaluating root-flip pattern 1940 out of 2048
# Evaluating root-flip pattern 1960 out of 2048
# Evaluating root-flip pattern 1980 out of 2048
# Evaluating root-flip pattern 2000 out of 2048
# Evaluating root-flip pattern 2020 out of 2048
# Evaluating root-flip pattern 2040 out of 2048
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Recursive Pulse Design for a 3-Segment FLEET EPI scan

# %%
# Design the pulses
Nseg = 3 # number of EPI segments/RF Pulses
tb = 4
N = 2000
seSeq = True
tbRef = 8 # time-bandwidth of ref pulse
[pulses, pu = rf.slr.dzRecursiveRF(Nseg, tb, N, seSeq, tbRef)

# %%
# Plot them
pl.LinePlot(pulses.T, mode = 'real')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-b223554d18a9> in <module>
#       1 # Plot them
# ----> 2 pl.LinePlot(pulses.T, mode = 'real')
#
# AttributeError: 'tuple' object has no attribute 'T'

# %%
# Simulate them
Mxy = np.zeros((np.size(np.arange(-4*tb, 4*tb, 0.01)), Nseg), dtype = complex)
Mz = np.ones(np.size(np.arange(-4*tb, 4*tb, 0.01)))
for ii in range(0, Nseg):    
    [a, b] = rf.sim.abrm(pulses[:, ii], np.arange(-4*tb, 4*tb, 0.01), True)
    Mxy[:, ii] = 2*Mz*np.multiply(np.conj(a),b)
    Mz = Mz*(1 - 2*np.abs(b)**2)

# %%
# Plot Mxy profiles
pl.LinePlot(Mxy.T)
# Out:
# <img src="data:image/png;base64,..." width="640">
